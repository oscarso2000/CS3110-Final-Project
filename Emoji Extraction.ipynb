# %%
import pandas as pd
df = pd.read_csv("./emo.txt")

# %%
df
# Out:
#                               Emojis
# 0                           hot_face
# 1                          cold_face
# 2                         woozy_face
# 3                         dizzy_face
# 4                     exploding_head
# 5                    cowboy_hat_face
# 6                      partying_face
# 7       smiling_face_with_sunglasses
# 8                          nerd_face
# 9                  face_with_monocle
# 10                     confused_face
# 11                      worried_face
# 12            slightly_frowning_face
# 13                     frowning_face
# 14              face_with_open_mouth
# 15                       hushed_face
# 16                   astonished_face
# 17                      flushed_face
# 18                     pleading_face
# 19     frowning_face_with_open_mouth
# 20                    anguished_face
# 21                      fearful_face
# 22           anxious_face_with_sweat
# 23             sad_but_relieved_face
# ...

# %%
for index, row in df.iterrows():
    print("  | \"" + row["Emojis"] + "\" -> Emoji." + row["Emojis"])
# Out:
#   | "hot_face" -> Emoji.hot_face
#   | "cold_face" -> Emoji.cold_face
#   | "woozy_face" -> Emoji.woozy_face
#   | "dizzy_face" -> Emoji.dizzy_face
#   | "exploding_head" -> Emoji.exploding_head
#   | "cowboy_hat_face" -> Emoji.cowboy_hat_face
#   | "partying_face" -> Emoji.partying_face
#   | "smiling_face_with_sunglasses" -> Emoji.smiling_face_with_sunglasses
#   | "nerd_face" -> Emoji.nerd_face
#   | "face_with_monocle" -> Emoji.face_with_monocle
#   | "confused_face" -> Emoji.confused_face
#   | "worried_face" -> Emoji.worried_face
#   | "slightly_frowning_face" -> Emoji.slightly_frowning_face
#   | "frowning_face" -> Emoji.frowning_face
#   | "face_with_open_mouth" -> Emoji.face_with_open_mouth
#   | "hushed_face" -> Emoji.hushed_face
#   | "astonished_face" -> Emoji.astonished_face
#   | "flushed_face" -> Emoji.flushed_face
#   | "pleading_face" -> Emoji.pleading_face
#   | "frowning_face_with_open_mouth" -> Emoji.frowning_face_with_open_mouth
# ...
